# %%
from nsepy import get_history
from datetime import datetime

# %%
start= datetime(2015,1,1)
end= datetime(2020,8,25)

# %%
data= get_history(symbol= 'IRCTC', start= start, end= end)

# %%
data
# Out:
#            Symbol Series  Prev Close    Open     High  ...    Volume      Turnover  Trades  Deliverable Volume %Deliverble
# Date                                                   ...
# 2019-10-14  IRCTC     EQ      320.00   626.0   743.80  ...  45270607  3.136853e+15  872378            13696306      0.3025
# 2019-10-15  IRCTC     EQ      727.75   736.0   747.40  ...  10530041  7.571972e+14  247733             1311908      0.1246
# 2019-10-16  IRCTC     EQ      713.15   714.0   721.00  ...   3476306  2.451928e+14   84792              770776      0.2217
# 2019-10-17  IRCTC     EQ      700.65   700.1   733.00  ...   5032930  3.563273e+14  128184             1254924      0.2493
# 2019-10-18  IRCTC     EQ      724.30   725.0   789.90  ...   9733230  7.471291e+14  235191              913567      0.0939
# ...           ...    ...         ...     ...      ...  ...       ...           ...     ...                 ...         ...
# ...
